# %%
# !ls
# Out:
# convert_weight_path.pth.tar  Data.zip	  README.md	   sample
# Data			     model	  repvgg.pth.tar   trainer.ipynb
# dataloader.py		     __pycache__  requirement.txt  visualize_data.ipynb

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Count the number of dada on each category

# %%
lab = pd.read_csv('./Data/labels.csv')

# %%
## label map
d = dict()
class_labels = dict()
print('Label map: ')
print('-----------------------------------------')
for dirs in os.listdir('./Data/myData'):
    count = len(os.listdir('./Data/myData/' + dirs))
    print(str(dirs) + '\t' + str(lab[lab.ClassId == int(dirs)].values[0][1]))
    d[dirs+' => '+lab[lab.ClassId == int(dirs)].values[0][1]] = count
    class_labels[int(dirs)] = lab[lab.ClassId == int(dirs)].values[0][1]
# Out:
# Label map:
# -----------------------------------------
# 24	Road narrows on the right
# 1	Speed limit (30km/h)
# 30	Beware of ice/snow
# 33	Turn right ahead
# 31	Wild animals crossing
# 21	Double curve
# 22	Bumpy road
# 19	Dangerous curve to the left
# 4	Speed limit (70km/h)
# 17	No entry
# 34	Turn left ahead
# 32	End of all speed and passing limits
# 41	End of no passing
# 35	Ahead only
# 16	Vechiles over 3.5 metric tons prohibited
# 26	Traffic signals
# 28	Children crossing
# 8	Speed limit (120km/h)
# 0	Speed limit (20km/h)
# 40	Roundabout mandatory
# 14	Stop
# 10	No passing for vechiles over 3.5 metric tons
# 5	Speed limit (80km/h)
# 12	Priority road
# 39	Keep left
# 37	Go straight or left
# 25	Road work
# 15	No vechiles
# 3	Speed limit (60km/h)
# 7	Speed limit (100km/h)
# 2	Speed limit (50km/h)
# 18	General caution
# 23	Slippery road
# 6	End of speed limit (80km/h)
# 20	Dangerous curve to the right
# 42	End of no passing by vechiles over 3.5 metric tons
# 36	Go straight or right
# 29	Bicycles crossing
# 38	Keep right
# 9	No passing
# 13	Yield
# 11	Right-of-way at the next intersection
# 27	Pedestrians

# %%
plt.figure(figsize = (20, 50))
sns.barplot(y = list(d.keys()), x = list(d.values()), palette = 'Set3')
plt.ylabel('Label')
plt.xlabel('Count of Samples/Observations')
# Out:
# Text(0.5, 0, 'Count of Samples/Observations')

# %% [markdown]
# ## Sample Images of Dataset

# %%
from dataloader import TrafficSignDataset

# %%
dataset = TrafficSignDataset(image_dir='./Data/myData/', label_file='./Data/labels.csv', target_shape=(32, 32))
print('------------------------------------------------------')
print('The number of data: ', len(dataset))
# Out:
# Create data for class Road narrows on the right: 100%|████████| 510/510 [00:00<00:00, 383900.76it/s]
# Create data for class Speed limit (30km/h): 100%|███████████| 4920/4920 [00:00<00:00, 420241.84it/s]
# Create data for class Beware of ice/snow: 100%|███████████████| 840/840 [00:00<00:00, 227700.86it/s]
# Create data for class Turn right ahead: 100%|███████████████| 1288/1288 [00:00<00:00, 306407.10it/s]
# Create data for class Wild animals crossing: 100%|██████████| 1470/1470 [00:00<00:00, 351077.72it/s]
# Create data for class Double curve: 100%|█████████████████████| 600/600 [00:00<00:00, 202021.55it/s]
# Create data for class Bumpy road: 100%|███████████████████████| 720/720 [00:00<00:00, 397826.23it/s]
# Create data for class Dangerous curve to the left: 100%|██████| 390/390 [00:00<00:00, 220901.90it/s]
# Create data for class Speed limit (70km/h): 100%|███████████| 3750/3750 [00:00<00:00, 417183.17it/s]
# Create data for class No entry: 100%|███████████████████████| 2100/2100 [00:00<00:00, 487520.81it/s]
# Create data for class Turn left ahead: 100%|██████████████████| 780/780 [00:00<00:00, 527075.42it/s]
# Create data for class End of all speed and passing limits: 100%|█| 450/450 [00:00<00:00, 181693.95it
# Create data for class End of no passing: 100%|████████████████| 450/450 [00:00<00:00, 200322.31it/s]
# Create data for class Ahead only: 100%|█████████████████████| 2280/2280 [00:00<00:00, 422319.96it/s]
# Create data for class Vechiles over 3.5 metric tons prohibited: 100%|█| 780/780 [00:00<00:00, 210443
# Create data for class Traffic signals: 100%|████████████████| 1140/1140 [00:00<00:00, 554313.30it/s]
# Create data for class Children crossing: 100%|██████████████| 1020/1020 [00:00<00:00, 329573.23it/s]
# Create data for class Speed limit (120km/h): 100%|██████████| 2670/2670 [00:00<00:00, 638071.43it/s]
# Create data for class Speed limit (20km/h): 100%|█████████████| 451/451 [00:00<00:00, 333444.58it/s]
# Create data for class Roundabout mandatory: 100%|█████████████| 660/660 [00:00<00:00, 425621.25it/s]
# Create data for class Stop: 100%|███████████████████████████| 1470/1470 [00:00<00:00, 147552.45it/s]
# Create data for class No passing for vechiles over 3.5 metric tons: 100%|█| 3810/3810 [00:00<00:00,
# Create data for class Speed limit (80km/h): 100%|███████████| 3510/3510 [00:00<00:00, 351486.38it/s]
# Create data for class Priority road: 100%|██████████████████| 3990/3990 [00:00<00:00, 576799.92it/s]
# Create data for class Keep left: 100%|████████████████████████| 570/570 [00:00<00:00, 708161.52it/s]
# Create data for class Go straight or left: 100%|██████████████| 390/390 [00:00<00:00, 112224.11it/s]
# Create data for class Road work: 100%|██████████████████████| 2850/2850 [00:00<00:00, 354500.78it/s]
# Create data for class No vechiles: 100%|████████████████████| 1170/1170 [00:00<00:00, 471315.37it/s]
# Create data for class Speed limit (60km/h): 100%|███████████| 2670/2670 [00:00<00:00, 454828.68it/s]
# Create data for class Speed limit (100km/h): 100%|██████████| 2730/2730 [00:00<00:00, 590503.32it/s]
# Create data for class Speed limit (50km/h): 100%|███████████| 2610/2610 [00:00<00:00, 819702.99it/s]
# Create data for class General caution: 100%|████████████████| 2280/2280 [00:00<00:00, 354619.09it/s]
# Create data for class Slippery road: 100%|████████████████████| 960/960 [00:00<00:00, 462394.56it/s]
# Create data for class End of speed limit (80km/h): 100%|██████| 780/780 [00:00<00:00, 225671.32it/s]
# Create data for class Dangerous curve to the right: 100%|██████| 660/660 [00:00<00:00, 65307.18it/s]
# Create data for class End of no passing by vechiles over 3.5 metric tons: 100%|█| 450/450 [00:00<00:
# Create data for class Go straight or right: 100%|█████████████| 720/720 [00:00<00:00, 407159.08it/s]
# Create data for class Bicycles crossing: 100%|████████████████| 510/510 [00:00<00:00, 345740.27it/s]
# Create data for class Keep right: 100%|█████████████████████| 3930/3930 [00:00<00:00, 437289.16it/s]
# Create data for class No passing: 100%|█████████████████████| 2790/2790 [00:00<00:00, 387525.52it/s]
# Create data for class Yield: 100%|██████████████████████████| 4080/4080 [00:00<00:00, 385778.77it/s]
# Create data for class Right-of-way at the next intersection: 100%|█| 2490/2490 [00:00<00:00, 139701.
# Create data for class Pedestrians: 100%|███████████████████████| 450/450 [00:00<00:00, 71588.73it/s]
# ------------------------------------------------------
# The number of data:  73139

# %%
#imshow random images
dataset.visualize_random_images(nb_row=4, nb_col=4)
